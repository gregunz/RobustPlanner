# %%
import pandas as pd
import numpy as np

# %%
data_df = pd.read_csv("data/2017-09/2017-09-13istdaten.csv", sep=";")
# Out:
# /home/charles/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (6,7,8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
tr_col_name = {
    'BETRIEBSTAG': 'TRIP_DATE',
    'FAHRT_BEZEICHNER': 'TRIP_ID',
    'BETREIBER_ID': 'OPERATOR_ID',
    'BETREIBER_ABK': 'OPERATOR_SHORT_NAME',
    'BETREIBER_NAME': 'OPERATOR_NAME',
    'PRODUKT_ID': 'TRANSPORT_TYPE',
    'LINIEN_ID': 'LINE_ID', # TRAIN_NB
    'LINIEN_TEXT': 'LINE_TYPE', #RE, IC, IR
    'UMLAUF_ID': 'CYCLE_ID',
    'VERKEHRSMITTEL_TEXT': 'TRANSPORT_TYPE',
    'ZUSATZFAHRT_TF': 'IS_ADDITIONAL_TRIP',
    'FAELLT_AUS_TF': 'HAS_TRIP_FAILED',
    'BPUIC': 'BPUIC', #UNKOWN
    'HALTESTELLEN_NAME': 'STOP_STATION_NAME',
    'ANKUNFTSZEIT': 'ARRIVAL_TIME',
    'AN_PROGNOSE': 'ACTUAL_ARRIVAL_TIME', #When AN_PROGNOSE_STATUS == GESCHAETZT
    'AN_PROGNOSE_STATUS': 'ACTUAL_ARRIVAL_TIME_STATUS',
    'ABFAHRTSZEIT': 'DEPARTURE_TIME',
    'AB_PROGNOSE': 'ACTUAL_DEPARTURE_TIME',
    'AB_PROGNOSE_STATUS':'ACTUAL_DEPARTURE_TIME_STATUS',
    'DURCHFAHRT_TF': 'PASS_THROUGH' #true if the transport does not stop there
}

# %%
data_df_tr = data_df.rename(columns=tr_col_name)

# %%
# Extract list of stop from metadata file.
with open("data/metadata/BFKOORD_GEO") as file:
    metadata = file.readlines()
    
metadata_cleaned = [line.split("%") for line in metadata]
metadata_cleaned = [[line[0].split(), line[1][1:-1]] for line in  metadata_cleaned]
metadata_cleaned = [[line[0][0], line[0][1], line[0][2], line[0][3], line[1]] for line in metadata_cleaned]

metadata_df = pd.DataFrame(metadata_cleaned, columns=["StationID", "Longitude", "Latitude", "Height", "Remark"])

metadata_df["Longitude"] = pd.to_numeric(metadata_df["Longitude"])
metadata_df["Latitude"] = pd.to_numeric(metadata_df["Latitude"])

# %%
def distance_from_gps_coord(s_lat, s_lon, e_lat, e_lon):
    """
        Compute distance from two points in gps coordinates.
        Output distance in kilometers.
    """
    s_lat = np.radians(s_lat)
    s_lon = np.radians(s_lon)
    e_lat = np.radians(e_lat)
    e_lon = np.radians(e_lon)
    
    return 6371.01 * np.arccos(np.sin(s_lat)* np.sin(e_lat) + np.cos(s_lat)* np.cos(e_lat)* np.cos(s_lon - e_lon))

# %%
# Retrieve stops near Zurich main station
zurichHB = metadata_df[metadata_df.Remark == "Zürich HB"]

metadata_df["dist"] = metadata_df.apply(lambda x: distance_from_gps_coord(zurichHB.Latitude, zurichHB.Longitude, x.Latitude, x.Longitude), axis=1)
zurich_stops_df = metadata_df[metadata_df["dist"] < 10]
zurich_stops_df.head()
# Out:
#      StationID  Longitude   Latitude Height                  Remark      dist
# 74     0000176   8.521961  47.351679      0  Zimmerberg-Basistunnel  3.250675
# 2084   8502220   8.434713  47.390882    442                  Urdorf  8.065921
# 2085   8502221   8.437543  47.357432    488          Birmensdorf ZH  8.067443
# 2086   8502222   8.468175  47.325896    528     Bonstetten-Wettswil  7.951700
# 2092   8502229   8.430330  47.380971    456       Urdorf Weihermatt  8.277832

# %%
stops = list(zurich_stops_df['Remark'])

# %%
col_of_interest = ['TRIP_DATE', 'LINE_ID', 'HAS_TRIP_FAILED', 'STOP_STATION_NAME',
                   'ARRIVAL_TIME', 'ACTUAL_ARRIVAL_TIME', 'ACTUAL_ARRIVAL_TIME_STATUS',
                   'DEPARTURE_TIME', 'ACTUAL_DEPARTURE_TIME', 'ACTUAL_DEPARTURE_TIME_STATUS',
                   'PASS_THROUGH']

# %%
#filter out uninteresting cities
data_df_tr = data_df_tr[data_df_tr['STOP_STATION_NAME'].isin(stops)]
#data_df_tr = data_df_tr[data_df_tr['ACTUAL_ARRIVAL_TIME_STATUS'] == 'GESCHAETZT']
#data_df_tr = data_df_tr[data_df_tr['ACTUAL_DEPARTURE_TIME_STATUS'] == 'GESCHAETZT']
data_df_tr[col_of_interest]#[data_df_tr["LINE_ID"] == 11]#.dtypes
# Out:
#          TRIP_DATE     LINE_ID  HAS_TRIP_FAILED             STOP_STATION_NAME  \
# 443     13.09.2017          10            False                     Zürich HB
# 685     13.09.2017          11            False                     Zürich HB
# 1835    13.09.2017          12            False                     Zürich HB
# 4582    13.09.2017        1251             True                     Zürich HB
# 4814    13.09.2017        1255            False                     Zürich HB
# 4873    13.09.2017        1256            False                     Zürich HB
# 4975    13.09.2017        1258             True                     Zürich HB
# 5039    13.09.2017        1260             True                     Zürich HB
# 5618    13.09.2017          13            False                     Zürich HB
# 5630    13.09.2017          14            False                     Zürich HB
# 5631    13.09.2017        1408            False                     Zürich HB
# 5633    13.09.2017        1410            False                     Zürich HB
# 5636    13.09.2017        1411            False                     Zürich HB
# 5638    13.09.2017        1429            False                     Zürich HB
# 5685    13.09.2017        1431            False                     Zürich HB
# 7277    13.09.2017          15            False                     Zürich HB
# 7300    13.09.2017        1507            False                     Zürich HB
# 7301    13.09.2017        1507            False              Zürich Flughafen
# 7308    13.09.2017        1508            False                     Zürich HB
# 7322    13.09.2017        1509            False                     Zürich HB
# 7323    13.09.2017        1509            False              Zürich Flughafen
# 7336    13.09.2017        1510            False              Zürich Flughafen
# 7337    13.09.2017        1510            False                     Zürich HB
# 7354    13.09.2017        1511            False                     Zürich HB
# 7355    13.09.2017        1511            False              Zürich Flughafen
# 7368    13.09.2017        1512            False              Zürich Flughafen
# 7369    13.09.2017        1512            False                     Zürich HB
# 7386    13.09.2017        1513            False                     Zürich HB
# 7387    13.09.2017        1513            False              Zürich Flughafen
# 7400    13.09.2017        1514            False              Zürich Flughafen
# ...            ...         ...              ...                           ...
# 880845  13.09.2017  85:882:660            False         Bassersdorf, Schmitte
# 880881               NaN                   NaN                     PROGNOSE
# 880882  13.09.2017 22:44   13.09.2017 22:44:40                     PROGNOSE
# 880883  13.09.2017 22:44   13.09.2017 22:45:34                     PROGNOSE
# 880884  13.09.2017 22:45   13.09.2017 22:46:16                     PROGNOSE
# 880915  13.09.2017 23:41   13.09.2017 23:41:18                     PROGNOSE
# 880916               NaN                   NaN                     PROGNOSE
# 880917  13.09.2017 23:44   13.09.2017 23:44:42                     PROGNOSE
# 880918  13.09.2017 23:44   13.09.2017 23:45:45                     PROGNOSE
# 880919  13.09.2017 23:45   13.09.2017 23:46:13                     PROGNOSE
# 880950  13.09.2017 21:41   13.09.2017 21:44:08                     PROGNOSE
# 880951               NaN                   NaN                     PROGNOSE
# 880952  13.09.2017 21:45   13.09.2017 21:46:37                     PROGNOSE
# 880953  13.09.2017 21:45   13.09.2017 21:47:31                     PROGNOSE
# 880954  13.09.2017 21:46   13.09.2017 21:48:13                     PROGNOSE
# 880985  13.09.2017 23:11   13.09.2017 23:11:18                     PROGNOSE
# 880986               NaN                   NaN                     PROGNOSE
# 880987  13.09.2017 23:14   13.09.2017 23:14:19                     PROGNOSE
# 880988  13.09.2017 23:14   13.09.2017 23:15:52                     PROGNOSE
# 880989  13.09.2017 23:15   13.09.2017 23:16:34                     PROGNOSE
# 881020  14.09.2017 00:11   14.09.2017 00:11:23                     PROGNOSE
# 881021               NaN                   NaN                     PROGNOSE
# 881022  14.09.2017 00:14   14.09.2017 00:15:25                     PROGNOSE
# 881023  14.09.2017 00:14   14.09.2017 00:16:19                     PROGNOSE
# 881024  14.09.2017 00:15   14.09.2017 00:17:01                     PROGNOSE
#
#         PASS_THROUGH
# 443            False
# 685            False
# 1835           False
# 4582           False
# 4814           False
# 4873           False
# 4975           False
# 5039           False
# 5618           False
# 5630           False
# 5631           False
# 5633           False
# 5636           False
# 5638           False
# 5685           False
# 7277           False
# 7300           False
# 7301           False
# 7308           False
# 7322           False
# 7323           False
# 7336           False
# 7337           False
# 7354           False
# 7355           False
# 7368           False
# 7369           False
# 7386           False
# 7387           False
# 7400           False
# ...              ...
# 880845         False
# 880846         False
# 880847         False
# 880848         False
# 880849         False
# 880880         False
# 880881         False
# 880882         False
# 880883         False
# 880884         False
# 880915         False
# 880916         False
# 880917         False
# 880918         False
# 880919         False
# 880950         False
# 880951         False
# 880952         False
# 880953         False
# 880954         False
# 880985         False
# 880986         False
# 880987         False
# 880988         False
# 880989         False
# 881020         False
# 881021         False
# 881022         False
# 881023         False
# 881024         False
#
# [235844 rows x 11 columns]

# %%
#deal with date
data_df_tr['DEPARTURE_TIME'] = pd.to_datetime(data_df_tr['DEPARTURE_TIME'])
data_df_tr['ACTUAL_DEPARTURE_TIME'] = pd.to_datetime(data_df_tr['ACTUAL_DEPARTURE_TIME'])
data_df_tr['ARRIVAL_TIME'] = pd.to_datetime(data_df_tr['ARRIVAL_TIME'])
data_df_tr['ACTUAL_ARRIVAL_TIME'] = pd.to_datetime(data_df_tr['ACTUAL_ARRIVAL_TIME'])

# %%
from geopy.distance import distance as geo_dist
#geo_dist((lat1, long1), (lat2, long2))geo_dist

def getLineID(df, station, time):
    df = df.copy()
    df = df[df['STOP_STATION_NAME'] == station][df['DEPARTURE_TIME'] > time]\
        [df['DEPARTURE_TIME'] < time + pd.Timedelta(minutes=60)]
    df = df.dropna(subset=['DEPARTURE_TIME'])
    #df = df[np.isfinite(df['DEPARTURE_TIME'])]
    return list(df['TRIP_ID'])#list(df['LINE_ID'])
def viewLine(df, line_id):
    return df[df["TRIP_ID"] == line_id]#df[df["LINE_ID"] == line_id]
def dist_between_station(df, station1, station2):
    df=df.copy()
    df = df[df['Remark'].isin([station1, station2])]
    df.index = df['Remark']
    df = df[['Longitude', 'Latitude']]
    s1 = df.loc[station1]
    s2 = df.loc[station2]
    return geo_dist((s1.Latitude,s1.Longitude), (s2.Latitude,s2.Longitude))
def getNextStations(df, line_id, station):
    df = df.copy()
    df = viewLine(df, line_id)
    #assumption it is already sorted
    df.index = df['STOP_STATION_NAME']
    df = df.loc[station:]
    return df
def getNextStation(df, line_id, station):
    #print(line_id)
    #print(station)
    df = df.copy()
    df = getNextStations(df, line_id, station)
    if df.shape[0] > 1:
        return df.iloc[1]
    else:
        None
def getNextStations2(df, line_id, station):
    df = df.copy()
    df = viewLine(df, line_id)
    df = df.sort_values('ARRIVAL_TIME')
    select_next = False
    nexts = []
    for index, row in df.iterrows():
        if select_next:
            nexts.append(row)
            select_next = False
        if(row['STOP_STATION_NAME'] == station):
            select_next = True
    return nexts
def getLongLat(df, station):
    df=df.copy()
    df = df[df['Remark'] == station]
    df.index = df['Remark']
    df = df[['Longitude', 'Latitude']]
    s1 = df.loc[station]
    return (s1.Latitude,s1.Longitude)

#To be run once for all station and result save in a map (or table) 
def getNearByStation(df, station):
    df = df.copy()
    loc = getLongLat(df, station)
    df = df.dropna(subset=['Remark'])
    df['newDist'] = df.apply(lambda x: geo_dist((x.Latitude, x.Longitude), loc), axis=1)
    df = df[df['newDist'] < 0.1]
    return df
getNearByStation(metadata_df, 'Zürich, Bürkliplatz')
#geo_dist((lat1, long1), (lat2, long2))
#(last_station='Zurich', medium=(walk, line, trainNb), ...)
# Out:
#       StationID  Longitude   Latitude Height                    Remark  \
# 2800    8503651   8.540788  47.366010    406  Zürich Bürkliplatz (See)
# 21684   8591105   8.540341  47.366824    408       Zürich, Bürkliplatz
#
#            dist                 newDist
# 2800   1.353655  0.09659217848548045 km
# 21684  1.262448                  0.0 km

# %%
getNextStations2(data_df_tr, '85:3849:80257-02002-1','Zürich, Bürkliplatz')#[col_of_interest]
# Out:
# TRIP_DATE                                          13.09.2017
# TRIP_ID                                 85:3849:80257-02002-1
# OPERATOR_ID                                           85:3849
# OPERATOR_SHORT_NAME                                   VBZ Fpl
# OPERATOR_NAME                   Verkehrsbetriebe Zürich INFO+
# TRANSPORT_TYPE                                           Tram
# LINE_ID                                           85:3849:002
# LINE_TYPE                                                   2
# CYCLE_ID                                                10001
# TRANSPORT_TYPE                                            NaN
# IS_ADDITIONAL_TRIP                                      False
# HAS_TRIP_FAILED                                         False
# BPUIC                                                 8576200
# STOP_STATION_NAME                     Zürich, Wildbachstrasse
# ARRIVAL_TIME                              2017-09-13 10:31:00
# ACTUAL_ARRIVAL_TIME                       2017-09-13 10:34:04
# ACTUAL_ARRIVAL_TIME_STATUS                           PROGNOSE
# DEPARTURE_TIME                                            NaT
# ACTUAL_DEPARTURE_TIME                                     NaT
# ACTUAL_DEPARTURE_TIME_STATUS                         PROGNOSE
# PASS_THROUGH                                            False
# Name: 121135, dtype: object

# %%
#getNextStation(data_df_tr, lines[0], 'Zürich HB').STOP_STATION_NAME

# %%
dist_between_station(metadata_df, 'Zürich HB', 'Bassersdorf, Bahnhof')
# Out:
# Distance(9.347745240044421)

# %%
viewLine(data_df_tr, 18390)[col_of_interest]
# Out:
# Empty DataFrame
# Columns: [TRIP_DATE, LINE_ID, HAS_TRIP_FAILED, STOP_STATION_NAME, ARRIVAL_TIME, ACTUAL_ARRIVAL_TIME, ACTUAL_ARRIVAL_TIME_STATUS, DEPARTURE_TIME, ACTUAL_DEPARTURE_TIME, ACTUAL_DEPARTURE_TIME_STATUS, PASS_THROUGH]
# Index: []

# %%
getLineID(data_df_tr, start_station, departure_time)[0]
viewLine(data_df_tr, '85:3849:80257-02002-1')[col_of_interest]
# Out:
# /home/charles/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#          TRIP_DATE      LINE_ID  HAS_TRIP_FAILED  \
# 121089  13.09.2017  85:3849:002            False
# 121090  13.09.2017  85:3849:002            False
# 121091  13.09.2017  85:3849:002            False
# 121092  13.09.2017  85:3849:002            False
# 121093  13.09.2017  85:3849:002            False
# 121094  13.09.2017  85:3849:002            False
# 121095  13.09.2017  85:3849:002            False
# 121096  13.09.2017  85:3849:002            False
# 121097  13.09.2017  85:3849:002            False
# 121098  13.09.2017  85:3849:002            False
# 121099  13.09.2017  85:3849:002            False
# 121100  13.09.2017  85:3849:002            False
# 121101  13.09.2017  85:3849:002            False
# 121102  13.09.2017  85:3849:002            False
# 121103  13.09.2017  85:3849:002            False
# 121104  13.09.2017  85:3849:002            False
# 121105  13.09.2017  85:3849:002            False
# 121106  13.09.2017  85:3849:002            False
# 121107  13.09.2017  85:3849:002            False
# 121108  13.09.2017  85:3849:002            False
# 121109  13.09.2017  85:3849:002            False
# 121110  13.09.2017  85:3849:002            False
# 121111  13.09.2017  85:3849:002            False
# 121112  13.09.2017  85:3849:002            False
# 121115  13.09.2017  85:3849:002            False
# 121116  13.09.2017  85:3849:002            False
# 121117  13.09.2017  85:3849:002            False
# 121118  13.09.2017  85:3849:002            False
# 121119  13.09.2017  85:3849:002            False
# 121120  13.09.2017  85:3849:002            False
# 121121  13.09.2017  85:3849:002            False
# 121122  13.09.2017  85:3849:002            False
# 121123  13.09.2017  85:3849:002            False
# 121124  13.09.2017  85:3849:002            False
# 121125  13.09.2017  85:3849:002            False
# 121140   2017-09-13 10:19:47                     PROGNOSE         False
# 121141   2017-09-13 10:19:47                     PROGNOSE         False
# 121142   2017-09-13 10:19:47                     PROGNOSE         False
# 121143   2017-09-13 10:19:47                     PROGNOSE         False
# 121144   2017-09-13 10:19:47                     PROGNOSE         False
# 121145   2017-09-13 10:19:47                     PROGNOSE         False
# 121146   2017-09-13 10:12:17                     PROGNOSE         False

# %%
departure_time + pd.Timedelta(minutes=60)
# Out:
# Timestamp('2017-09-13 09:15:00')

# %%
total_dist*1.1
# Out:
# Distance(11.371315194582124)

# %%
ds = ['Zürich HB', 'Zürich HB', 'Zürich Wiedikon']
'Zürich HB' not in ds
# Out:
# False

# %%
# def reduce_queue(q):
#     q2 = queue.Queue()
#     all_elem = map()
#     while(not q.empty()):
#         elem = q.get()
#         q2.put(elem)
#         if elem in all_elem:

# %%
data_df_tr['STOP_STATION_NAME'].unique()
# Out:
# array(['Zürich HB', 'Zürich Flughafen', 'Bassersdorf', 'Zürich Wipkingen',
#        'Zürich Oerlikon', 'Glattbrugg', 'Zürich Hardbrücke',
#        'Zürich Stadelhofen', 'Thalwil', 'Zürich Enge', 'Zürich Wiedikon',
#        'Dietlikon', 'Stettbach', 'Zürich Altstetten', 'Schlieren',
#        'Glanzenberg', 'Urdorf', 'Urdorf Weihermatt', 'Birmensdorf ZH',
#        'Bonstetten-Wettswil', 'Regensdorf-Watt', 'Zürich Affoltern',
#        'Zürich Seebach', 'Zürich Tiefenbrunnen', 'Zollikon',
#        'Küsnacht Goldbach', 'Küsnacht ZH', 'Erlenbach ZH', 'Opfikon',
#        'Kloten Balsberg', 'Kloten', 'Wallisellen', 'Zürich Wollishofen',
#        'Kilchberg', 'Rüschlikon', 'Rümlang', 'Dübendorf',
#        'Schwerzenbach ZH', 'Zürich,Kalkbreite/Bhf.Wiedikon',
#        'Zürich, Lochergut', 'Zürich, Zypressenstrasse',
#        'Zürich, Albisriederplatz', 'Zürich, Letzigrund',
#        'Zürich, Freihofstrasse', 'Zürich, Kappeli',
#        'Zürich, Grimselstrasse', 'Zürich, Lindenplatz',
#        'Zürich, Bachmattstrasse', 'Zürich, Farbhof',
#        'Zürich, Bezirksgebäude', 'Zürich, Stauffacher',
#        'Zürich, Sihlstrasse', 'Zürich, Paradeplatz',
#        'Zürich, Börsenstrasse', 'Zürich, Bürkliplatz', 'Zürich, Bellevue',
#        'Zürich, Opernhaus', 'Zürich, Kreuzstrasse',
#        'Zürich, Feldeggstrasse', 'Zürich, Höschgasse',
#        'Zürich, Fröhlichstrasse', 'Zürich, Wildbachstrasse',
#        'Zürich, Rentenanstalt', 'Zürich, Tunnelstrasse',
#        'Zürich, Stockerstrasse', 'Zürich, Löwenplatz',
#        'Zürich, Bahnhofplatz/HB', 'Zürich, Central', 'Zürich, Neumarkt',
#        'Zürich, Kunsthaus', 'Zürich, Hottingerplatz', 'Zürich, Römerhof',
#        'Zürich, Hölderlinstrasse', 'Zürich, Klusplatz',
#        'Zürich, Hubertus', 'Zürich, Siemens', 'Zürich, Fellenbergstrasse',
#        'Zürich, Albisrieden', 'Zürich, Escher-Wyss-Platz',
#        'Zürich, Dammweg', 'Zürich, Quellenstrasse', 'Zürich, Limmatplatz',
#        'Zürich, Museum für Gestaltung', 'Zürich, Sihlquai/HB',
#        'Zürich, Bahnhofquai/HB', 'Zürich, Rudolf-Brun-Brücke',
#        'Zürich, Rathaus', 'Zürich, Helmhaus', 'Zürich, Schiffbau',
#        'Zürich, Technopark', 'Zürich, Toni-Areal', 'Zürich, Sportweg',
#        'Zürich, Aargauerstrasse', 'Zürich, Würzgraben',
#        'Zürich, Butzenstrasse', 'Zürich, Morgental',
#        'Zürich, Post Wollishofen', 'Zürich, Billoweg',
#        'Zürich, Brunaustrasse', 'Zürich, Museum Rietberg',
#        'Zürich, Kantonsschule', 'Zürich, Platte', 'Zürich, Voltastrasse',
#        'Zürich, Kirche Fluntern', 'Zürich, Waffenplatzstrasse',
#        'Zürich, Sihlcity Nord', 'Zürich, Saalsporthalle',
#        'Zürich, Laubegg', 'Zürich, Wollishofen',
#        'Zürich, Universität Irchel', 'Zürich, Langmauerstrasse',
#        'Zürich, Letzistrasse', 'Zürich, Kinkelstrasse',
#        'Zürich, Seilbahn Rigiblick', 'Zürich, Winkelriedstrasse',
#        'Zürich, Haldenbach', 'Zürich, ETH/Universitätsspital',
#        'Zürich, Toblerplatz', 'Zürich, Zürichbergstrasse',
#        'Zürich, Susenbergstrasse', 'Zürich, Zoo', 'Zürich, Haldenegg',
#        'Zürich, Bahnhofstrasse/HB', 'Zürich, Rennweg',
#        'Zürich, Sonneggstrasse', 'Zürich, Ottikerstrasse',
#        'Zürich, Röslistrasse', 'Zürich, Schaffhauserplatz',
#        'Zürich, Guggachstrasse', 'Zürich, Milchbuck',
#        'Zürich, Tierspital', 'Zürich, Waldgarten',
#        'Zürich, Schörlistrasse', 'Zürich, Schwamendingerplatz',
#        'Zürich, Roswiesen', 'Zürich, Glattwiesen', 'Zürich, Probstei',
#        'Zürich, Mattenhof', 'Zürich, Werd', 'Zürich, Heerenwiesen',
#        'Zürich, Luegisland', 'Zürich, Luchswiesen', 'Zürich, Altried',
#        'Zürich, Hirzenbach', 'Zürich, Schmiede Wiedikon',
#        'Zürich, Goldbrunnenplatz', 'Zürich, Talwiesenstrasse',
#        'Zürich, Heuried', 'Zürich, Schaufelbergerstrasse',
#        'Zürich, Triemli', 'Zürich, Sternen Oerlikon',
#        'Zürich, Salersteig', 'Zürich, Berninaplatz',
#        'Zürich, Hirschwiesenstrasse', 'Zürich, Leutschenbach',
#        'Zürich, Oerlikerhus', 'Glattbrugg, Lindberghplatz',
#        'Glattbrugg, Bahnhof', 'Rümlang, Bäuler', 'Glattbrugg, Unterriet',
#        'Kloten Balsberg, Bahnhof', 'Zürich Flughafen, Bahnhof',
#        'Zürich Flughafen, Fracht', 'Zürich, Messe/Hallenstadion',
#        'Zürich, Fernsehstudio', 'Zürich, Auzelg',
#        'Zürich, Regensbergbrücke', 'Zürich, Bad Allenmoos',
#        'Zürich, Radiostudio', 'Zürich, Bucheggplatz', 'Zürich, Laubiweg',
#        'Zürich, Kronenstrasse', 'Zürich, Beckenhof',
#        'Zürich, Stampfenbachplatz', 'Zürich, Signaustrasse',
#        'Zürich, Hedwigsteig', 'Zürich, Wetlistrasse', 'Zürich, Burgwies',
#        'Zürich, Friedhof Enzenbühl', 'Zürich, Rehalp',
#        'Zürich, Englischviertelstrasse', 'Wallisellen, Herti',
#        'Wallisellen, Belair', 'Wallisellen, Bahnhof',
#        'Wallisellen, Glatt (Tram)', 'Wallisellen, Neugut',
#        'Dübendorf, Giessen', 'Dübendorf, Ringwiesen',
#        'Zürich, Wipkingerplatz', 'Zürich, Waidfussweg',
#        'Zürich, Eschergutweg', 'Zürich, Alte Trotte', 'Zürich, Schwert',
#        'Zürich, Meierhofplatz', 'Zürich, Zwielplatz', 'Zürich, Wartau',
#        'Zürich, Winzerstrasse', 'Zürich, Frankental', 'Zürich, Uetlihof',
#        'Zürich, Strassenverkehrsamt', 'Zürich, Albisgütli',
#        'Zürich, Felsenrainstrasse', 'Zürich, Seebacherplatz',
#        'Zürich, Seebach', 'Zürich, Förrlibuckstrasse',
#        'Zürich, Fischerweg', 'Zürich, Bernoulli-Häuser',
#        'Zürich, Hardturm', 'Zürich, Hardhof', 'Zürich, Tüffenwies',
#        'Zürich, Grünaustrasse', 'Zürich, Bändliweg', 'Zürich, Werdhölzli',
#        'Neue Forch', 'Maiacher', 'Zumikon', 'Waltikon', 'Zollikerberg',
#        'Spital Zollikerberg', 'Waldburg', 'Zürich Balgrist',
#        'Zürich Hegibachplatz', 'Zürich Kreuzplatz',
#        'Zürich Stadelhofen FB', 'Regensdorf-Watt, Bahnhof',
#        'Regensdorf, Althard', 'Regensdorf, Hardhölzli',
#        'Regensdorf, Querstrasse', 'Regensdorf, Pumpwerkstrasse',
#        'Regensdorf, Furtbächli', 'Adlikon b. R., Ziegelhütte',
#        'Schwerzenbach ZH, Bahnhof', 'Volketswil, Volkiland Chliriet',
#        'Zürich Flughafen, Werft', 'Zürich Flughafen, Werkhof',
#        'Zürich Flughafen, Im Rohr', 'Zürich Flughafen, OPC',
#        'Zürich Flughafen, REGA', 'Kloten, Obstgartenstrasse',
#        'Rümlang, Bahnhof', 'Rümlang, Oberdorf', 'Rümlang, Gemeindehaus',
#        'Rümlang, Hörnlistrasse', 'Rümlang, Letten', 'Zürich, Im Ebnet',
#        'Zürich, Birch-/Glatttalstrasse', 'Zürich, Ausserdorfstrasse',
#        'Dübendorf, Bahnhof', 'Dübendorf, Lindenplatz',
#        'Dübendorf, Unterdorf', 'Dübendorf, Memphis',
#        'Dübendorf, Im Grund', 'Dübendorf, Zwinggarten',
#        'Dübendorf, Chriesmatt', 'Dietlikon, Aegert',
#        'Dietlikon, Dübendorferstrasse', 'Dietlikon, Dornenstrasse',
#        'Dietlikon, Bahnhof', 'Dietlikon, Zentrum', 'Dietlikon, Hofwiesen',
#        'Dübendorf, City Center', 'Dübendorf, Meiershofstrasse',
#        'Dübendorf, Breitibach', 'Dübendorf, Sonnental',
#        'Dübendorf, Hoffnung', 'Dübendorf, Bettlistrasse',
#        'Dübendorf, Claridenstrasse', 'Dübendorf, Branzenäsch',
#        'Dübendorf, Sonnenberg', 'Dübendorf, Raubbühl',
#        'Dübendorf, Sunnhalde', 'Dübendorf, Kunsteisbahn',
#        'Dübendorf, Kreuzbühl', 'Dübendorf, Kirche Wil',
#        'Dübendorf, Grüzenstrasse', 'Dübendorf, Zelglistrasse',
#        'Dübendorf, Schwimmbad', 'Dübendorf, Alterszentrum',
#        'Dübendorf, Högler', 'Dübendorf, Wasserfurren',
#        'Dübendorf, Stadthaus', 'Dübendorf, Post', 'Dübendorf, Gfenn',
#        'Dübendorf, Lindenbühl', 'Dübendorf, Schossacher',
#        'Dübendorf, Bauhof', 'Dübendorf, Glärnischstrasse',
#        'Dübendorf, EMPA', 'Dübendorf, Hochbord Nord',
#        'Dübendorf, Hochbord Süd', 'Dübendorf, Heidenrietstrasse',
#        'Wallisellen, Frohheimstrasse', 'Wallisellen, Bodenackerstrasse',
#        'Wallisellen, Kaserne', 'Wallisellen, Steinacker',
#        'Glattbrugg, Zil', 'Opfikon, Austrasse', 'Opfikon, Neuwiesen',
#        'Opfikon, Schulstrasse', 'Glattbrugg, Halden',
#        'Glattbrugg, Lättenwiesen', 'Opfikon, Bahnhof', 'Opfikon, Aublick',
#        'Opfikon, Fernsicht', 'Opfikon, Grätzli', 'Opfikon, Grossacker',
#        'Opfikon, Vreniker', 'Opfikon, Dorf', 'Opfikon, Bubenholz',
#        'Glattbrugg, Glatthof', 'Glattbrugg, Zentrum',
#        'Kloten, Zum Wilden Mann', 'Kloten, Kirchgasse',
#        'Kloten, Rankstrasse', 'Kloten, Oberfeld', 'Kloten, Grubenstrasse',
#        'Bassersdorf, Talgüetli', 'Bassersdorf, Chlupfgasse',
#        'Bassersdorf, Schmitte', 'Bassersdorf, Bahnhof',
#        'Bassersdorf, Dietlikonerstr.', 'Bassersdorf, Bächli',
#        'Baltenswil', 'Brüttisellen, Zentrum', 'Dietlikon, Bahnhof/Bad',
#        'Bassersdorf, Löwen', 'Kloten, Bahnhof', 'Kloten, Mühle',
#        'Zürich, Ettenfeld', 'Glattbrugg, Frohbühlstrasse',
#        'Glattbrugg, Post', 'Glattbrugg, Riethofstrasse',
#        'Kloten, Balsberg Hardacher', 'Bassersdorf, Gemeindehaus',
#        'Wallisellen, Schäfligraben', 'Wallisellen, Bützacker',
#        'Wallisellen, Lindenplatz', 'Wallisellen, Alterszentrum',
#        'Wallisellen, Hallenbad', 'Wallisellen, Gemeindehaus',
#        'Wallisellen, Zentrum', 'Wallisellen, Guyer-Weg',
#        'Wallisellen, Zielacker', 'Wallisellen, Sportzentrum',
#        'Wallisellen, Blumenweg', 'Wallisellen, Furtbach',
#        'Wallisellen, Spitzacker', 'Wallisellen, Riedenerstrasse',
#        'Wallisellen, Rosenberg', 'Wallisellen, Florastrasse',
#        'Wallisellen, Guggenbühlstrasse', 'Wallisellen, Säntisstrasse',
#        'Wallisellen, Schulhaus Bürgli', 'Wallisellen, Haldenstrasse',
#        'Wallisellen, Friedhof', 'Dietlikon, Brandbachstrasse',
#        'Dietlikon, Industriestrasse', 'Dietlikon, Hörnligraben',
#        'Wallisellen, Ifang', 'Wallisellen, Glatt (Bus)',
#        'Brüttisellen, Haldenbrücke', 'Brüttisellen, Gsellhof',
#        'Wildpark-Höfli', 'Sihlau', 'Adliswil', 'Sood-Oberleimbach',
#        'Zürich Leimbach', 'Zürich Manegg', 'Zürich Brunau',
#        'Zürich Saalsporthalle', 'Zürich Giesshübel', 'Zürich Selnau',
#        'Zürich HB SZU', 'Zürich Binz', 'Uitikon Waldegg', 'Ringlikon',
#        'Uetliberg', 'Langnau am Albis, Dorf', 'Thalwil, Feldstrasse',
#        'Thalwil, Mühlebachplatz', 'Thalwil, Zentrum', 'Thalwil, Bahnhof',
#        'Bonstetten-Wettswil, Bahnhof', 'Wettswil a.A., Grund',
#        'Wettswil a.A., Moosstrasse', 'Wettswil a.A., Dorf',
#        'Wettswil a.A., Bäumlisächer', 'Wettswil a.A., Heidenchilen',
#        'Birmensdorf ZH, Landikon Bach', 'Birmensdorf ZH, Obere Risi',
#        'Birmensdorf ZH, Sternen/WSL', 'Waldegg, Leuen',
#        'Waldegg, Birmensdorferstrasse', 'Zürich, Sädlenweg',
#        'Birmensdorf ZH, Bahnhof', 'Birmensdorf ZH, Zentrum',
#        'Birmensdorf ZH, Weissenbrunnen', 'Birmensdorf ZH, Landikon Dorf',
#        'Stallikon, Diebis', 'Stallikon, Sellenbüren',
#        'Stallikon, Loomatt', 'Stallikon, Bleiki', 'Stallikon, Dorf',
#        'Stallikon, Langfuren', 'Stallikon, Aegerten',
#        'Stallikon, Gamlikon', 'Stallikon, Aumüli',
#        'Bonstetten, Sunnenberg', 'Bonstetten, Lärchenhof',
#        'Kloten, Freienberg', 'Wettswil a.A., Dettenbühl',
#        'Wettswil a.A., Schürli', 'Wettswil a.A., Beerimoos',
#        'Wettswil a.A., Chilenholzstr.', 'Wettswil a.A., Oberhusen',
#        'Wettswil a.A., Eggächer', 'Wettswil a.A., Heissächerstr.',
#        'Wettswil a.A., Strumbergächer', 'Wettswil a.A., Rehweid',
#        'Wettswil a.A., Langächer', 'Wettswil a.A., Schachenbach',
#        'Uitikon, Wängi', 'Uitikon, Gläseren', 'Uitikon, Roracher',
#        'Uitikon, Dorf', 'Uitikon, Halde', 'Waldegg, Post',
#        'Waldegg, Katholische Kirche', 'Ringlikon, Langwis',
#        'Ringlikon, Dorf', 'Ringlikon, Gättern',
#        'Uitikon Waldegg, Bahnhof', 'Thalwil, Trotte', 'Adliswil, Bahnhof',
#        'Adliswil, Rifertstrasse', 'Adliswil, Schulhaus Kopfholz',
#        'Adliswil, Rütistrasse/Wacht', 'Adliswil, Friedhof',
#        'Adliswil, Tobelhof', 'Adliswil, Wanneten-/Haldenstr.',
#        'Adliswil, Landolt-Junker-Str.', 'Adliswil, Büchel',
#        'Adliswil, Baumgartenweg', 'Thalwil, Post', 'Thalwil, Pilgerweg',
#        'Thalwil, Aegertli', 'Thalwil, Rudishaldenstrasse',
#        'Thalwil, Sonnenberg', 'Thalwil, Seehaldenstrasse',
#        'Rüschlikon, Park im Grüene', 'Rüschlikon, Moosstrasse',
#        'Rüschlikon, Eggrain', 'Rüschlikon, Loorain',
#        'Thalwil, Archstrasse', 'Erlenbach ZH, Bahnhof',
#        'Erlenbach ZH, Im Loo', 'Erlenbach ZH, Alterswohnheim',
#        'Erlenbach ZH, Im Vogelsang', 'Erlenbach ZH, Rankstrasse',
#        'Erlenbach ZH, Sandfelsenstr.', 'Erlenbach ZH, Erlenhöhe',
#        'Erlenbach ZH, Allmend', 'Erlenbach ZH, Föhrenstrasse',
#        'Erlenbach ZH, Chapf', 'Erlenbach ZH, Schützenhaus',
#        'Erlenbach ZH, Bahnhofstrasse', 'Erlenbach ZH,Kirchgemeindehaus',
#        'Erlenbach ZH, Schulhaus', 'Erlenbach ZH, Rebstrasse',
#        'Zürich, Herdernstrasse', 'Zürich, Hardplatz',
#        'Zürich, Güterbahnhof', 'Zürich, Bäckeranlage',
#        'Zürich, Militär-/Langstrasse', 'Zürich, SBB-Werkstätte',
#        'Zürich, Letzipark', 'Zürich, Luggwegstrasse', 'Zürich, Seidelhof',
#        'Zürich, Kanonengasse', 'Zürich, Sprecherstrasse',
#        'Zürich, Micafil', 'Schlieren, Mülligen',
#        'Schlieren, Gasometerbrücke', 'Schlieren, Wagonsfabrik',
#        'Schlieren, Zentrum/Bahnhof', 'Schlieren, Zentrum',
#        'Zürich, Rosengartenstrasse', 'Zürich, Birchdörfli',
#        'Zürich, Neuaffoltern', 'Zürich, Glaubtenstrasse',
#        'Zürich, Einfangstrasse', 'Zürich, Zehntenhausplatz',
#        'Zürich, Hungerbergstrasse', 'Zürich, Holzerhurd',
#        'Zürich, Lägernstrasse', 'Zürich, Rotbuchstrasse',
#        'Zürich, Nordstrasse', 'Zürich, Röntgenstrasse',
#        'Zürich, Helvetiaplatz', 'Zürich, Kernstrasse',
#        'Zürich, Zwinglihaus', 'Zürich, Höfliweg', 'Zürich, Friesenberg',
#        'Zürich, Friesenbergstrasse', 'Zürich, Im Hagacker',
#        'Zürich, Hegianwandweg', 'Zürich, Nürenbergstrasse',
#        'Zürich, Scheuchzerstrasse', 'Zürich, Vogelsangstrasse',
#        'Zürich, Spyriplatz', 'Zürich, Bethanien', 'Zürich, Hofstrasse',
#        'Zürich, Klosbach', 'Zürich, Hölderlinsteig',
#        'Zürich, Freiestrasse', 'Zürich, Botanischer Garten',
#        'Zürich, Hinterbergstrasse', 'Zürich, Sackzelg',
#        'Zürich, Schulhaus Altweg', 'Zürich, In der Ey',
#        'Zürich, Kapfstrasse', 'Zürich, Schlyfi',
#        'Zürich, Drusbergstrasse', 'Zürich, Waserstrasse',
#        'Zürich, Carl-Spitteler-Strasse', 'Zürich, Berghaldenstrasse',
#        'Zürich, Loorenstrasse', 'Zürich, Zweiackerstrasse',
#        'Zürich, Kienastenwies', 'Zürich, Neeserweg',
#        'Zürich, Feusisbergli', 'Zürich, Am Suteracher',
#        'Zürich, Loogarten', 'Zürich, Dunkelhölzli', 'Zürich, Solidapark',
#        'Zürich, Salzweg', 'Zürich, Rautihalde',
#        'Zürich, Schulhaus Buchlern', 'Zürich, Friedhof Eichbühl',
#        'Zürich, Schauenberg', 'Zürich, Lerchenrain',
#        'Zürich, Lerchenhalde', 'Zürich, ETH Hönggerberg',
#        'Zürich, Waidspital', 'Zürich, Pflegezentr. Käferberg',
#        'Zürich, Waidbadstrasse', 'Zürich, Appenzellerstrasse',
#        'Zürich, Am Börtli', 'Zürich, Kappenbühlweg',
#        'Zürich, Wieslergasse', 'Zürich, Michelstrasse',
#        'Zürich, Friedhof Hönggerberg', 'Zürich, Schützenhaus Höngg',
#        'Zürich, Strickhof', 'Zürich, Langensteinenstrasse',
#        'Zürich, Schäppiweg', 'Zürich, Germaniastrasse',
#        'Zürich, Rigiblick', 'Zürich, Spyristeig',
#        'Zürich, Krönleinstrasse', 'Zürich, Heubeeriweg',
#        'Zürich, Flobotstrasse', 'Zürich, Im Klösterli',
#        'Zürich, Schanzackerstrasse', 'Zürich, Hertensteinstrasse',
#        'Zürich, Buhnstrasse', 'Zürich, Friedhof Schwandenholz',
#        'Zürich, Staudenbühl', 'Zürich, Hürstholz',
#        'Zürich, Glaubtenstrasse Nord', 'Zürich, Althoos',
#        'Zürich, Maienweg', 'Zürich, Krematorium Nordheim',
#        'Zürich, Nordheimstrasse', 'Zürich, Berufswahlschule',
#        'Zürich, Lehenstrasse', 'Zürich, Rebbergsteig',
#        'Zürich, Kempfhofsteig', 'Zürich, Singlistrasse',
#        'Zürich, Segantinistrasse', 'Zürich, Giblenstrasse',
#        'Zürich, Heizenholz', 'Zürich, Geeringstrasse', 'Zürich, Rütihof',
#        'Zürich, Lettenstrasse', 'Zürich, Okenstrasse', 'Zürich, Aubrücke',
#        'Zürich, Herzogenmühlestrasse', 'Zürich, Tulpenstrasse',
#        'Zürich, Herbstweg', 'Zürich, Saatlenstrasse',
#        'Zürich, Riedgraben', 'Zürich, Hallenbad Oerlikon',
#        'Zürich, Oberwiesenstrasse', 'Zürich, Blumenfeldstrasse',
#        'Zürich, Aspholz', 'Zürich, Mühlacker', 'Zürich, Dreispitz',
#        'Zürich, Fronwald', 'Zürich, Unteraffoltern',
#        'Zürich, Schwandenholz', 'Zürich, Waidhof',
#        'Zürich, Maillartstrasse', 'Zürich, Stierenried',
#        'Zürich, Neunbrunnen', 'Zürich, Bollingerweg',
#        'Zürich, Max-Bill-Platz', 'Zürich, Friedhof Sihlfeld',
#        'Zürich, Bertastrasse', 'Zürich, Manesseplatz',
#        'Zürich, Hügelstrasse', 'Zürich, Brunau/Mutschellenstr.',
#        'Zürich, Thujastrasse', 'Zürich, Jugendherberge',
#        'Zürich, Kalchbühlweg', 'Zürich, Widmerstrasse', 'Zürich, Neubühl',
#        'Zürich, Waffenplatz-/Bederstr.', 'Zürich, Hürlimannplatz',
#        'Zürich, Brandschenkestrasse', 'Zürich, Gutstrasse',
#        'Zürich, Im Gut', 'Zürich, Langgrütstrasse',
#        'Zürich, Albisriederdörfli', 'Zürich, Untermoosstrasse',
#        'Zürich, Rautistrasse', 'Zürich, Weihersteig',
#        'Zürich, Im Wingert', 'Zürich, Hönggerberg',
#        'Zürich, Frymannstrasse', 'Zürich, Marbachweg', 'Zürich, Im Hüsli',
#        'Zürich, Sihlweidstrasse', 'Zürich, Mittelleimbach',
#        'Zürich, Manegg', 'Zürich, Verenastrasse', 'Zürich, Dorflinde',
#        'Zürich, Friedackerstrasse', 'Zürich, Frohburg',
#        'Zürich, Friedrichstrasse', 'Zürich, Himmeri',
#        'Zürich, Schönauring', 'Zürich, Köschenrüti',
#        'Zürich, Käshaldenstrasse', 'Zürich, Leimgrübelstrasse',
#        'Zürich, Binz', 'Zürich, Räffelstrasse', 'Zürich, Grubenstrasse',
#        'Zürich, Binz Center', 'Zürich, Altenhofstrasse',
#        'Zürich, Wonnebergstrasse', 'Zürich, Flühgasse',
#        'Zürich, EPI-Klinik', 'Zürich, Im Walder',
#        'Zürich, Bleulerstrasse', 'Zürich, Bristenstrasse',
#        'Zürich, Baslerstrasse', 'Zürich, Auzelg Ost',
#        'Zürich, Orionstrasse', 'Zürich, Bocklerstrasse',
#        'Zürich, Birchstrasse', 'Zürich, Chaletweg', 'Zürich, Mötteliweg',
#        'Zürich, Schumacherweg', 'Zürich, Winzerstrasse Süd',
#        'Zürich, Hohenklingensteig', 'Zürich, Winzerhalde',
#        'Zürich, Goldackerweg', 'Zürich, Triemlispital',
#        'Zürich, Glaubtenstrasse Süd', 'Zürich, Albisrank',
#        'Zürich, Flurstrasse', 'Zürich, Letzipark West',
#        'Zürich, Riedhofstrasse', 'Zürich, Schweighof', 'Zürich, Sihlcity',
#        'Zollikerberg, Station', 'Zollikerb., Langägerten/Spital',
#        'Zollikerberg, Spital', 'Zollikerberg, Hasenbart',
#        'Zollikerberg, Trichtenhauserm.', 'Zürich, Trichtisal',
#        'Zürich, Trichtenhausenfussweg', 'Zürich, Wiesliacher',
#        'Zürich, Segeten', 'Zürich, Stodolastrasse',
#        'Zürich, Witikon Zentrum', 'Zürich, Buchholz',
#        'Zürich, Schürgistrasse', 'Zürich, Schweizer Rück',
#        'Zürich, Sukkulentensammlung', 'Zürich, Landiwiese',
#        'Zürich, Rote Fabrik', 'Zürich, Seerose', 'Zürich, Stadtgrenze',
#        'Kilchberg ZH, Weinbergstrasse', 'Kilchberg ZH, Hornhaldenstr.',
#        'Kilchberg ZH, Paradiessteig', 'Kilchberg ZH, Sanatorium',
#        'Kilchberg ZH, Kreuzstrasse', 'Kilchberg ZH, Schwelle',
#        'Kilchberg ZH, Auf Brunnen', 'Kilchberg ZH, Kirche',
#        'Kilchberg ZH, Bahnhof', 'Kilchberg ZH,Schulhaus Dorfstr',
#        'Kilchberg ZH, Gottlieb-Binder', 'Kilchberg ZH, Altersheim',
#        'Adliswil, Hofackerstrasse', 'Adliswil, Ahornweg',
#        'Kilchberg ZH, Spital', 'Kilchberg ZH, Bendlikon',
#        'Kilchberg ZH, Lindt & Sprüngli', 'Kilchberg ZH, Schoorenstrasse',
#        'Kilchberg ZH, Stockengut', 'Kilchberg ZH, Mythenstrasse',
#        'Kilchberg ZH, Bächlerstrasse', 'Kilchberg ZH, Obere Hornhalde',
#        'Kilchberg ZH, Emilienheim', 'Kilchberg ZH, Breitloo',
#        'Kilchberg ZH, Schlimbergstr.', 'Kilchberg ZH, Paradiesstrasse',
#        'Kilchberg ZH, Schooren', 'Rüschlikon, Schlossstrasse',
#        'Rüschlikon, Bodengasse', 'Rüschlikon, Bahnhof',
#        'Rüschlikon, Weidstrasse', 'Rüschlikon, Langhaldenstrasse',
#        'Rüschlikon, Belvoir', 'Rüschlikon, Säumerstrasse',
#        'Adliswil, Krone', 'Adliswil, Tiefacker', 'Adliswil, Grüt',
#        'Zürich, Sunnau', 'Zürich, Dangelstrasse', 'Adliswil, Moos',
#        'Adliswil, Eichenweg', 'Adliswil, Badstrasse',
#        'Adliswil, Grundstrasse', 'Urdorf, Oberurdorf', 'Urdorf, Sonne',
#        'Urdorf, Spitzacker', 'Urdorf, Neumatt', 'Urdorf, Niederurdorf',
#        'Urdorf, Schlierenstrasse', 'Urdorf, Feldegg',
#        'Schlieren, Spital Limmattal', 'Schlieren, Kesslerstrasse',
#        'Schlieren, Bahnhof', 'Schlieren, Feldstrasse',
#        'Schlieren, Talacker-Windegg', 'Unterengstringen, Langwisen',
#        'Unterengstringen, Eckstein', 'Unterengstringen, Sennenbüel N',
#        'Weiningen ZH, Aegelsee', 'Weiningen ZH, Ausserdorf',
#        'Weiningen ZH, Lindenplatz', 'Weiningen ZH, Schulhaus',
#        'Unterengstringen, Aegelsee', 'Unterengstringen, Sennenbüel',
#        'Dietikon, Hofacker', 'Dietikon, Birmensdorferstrasse',
#        'Urdorf, Herweg', 'Urdorf, Luberzen', 'Schlieren, Steinacker',
#        'Schlieren, Reitmen', 'Oberengstringen, Eggbühl',
#        'Oberengstringen, Lanzrain', 'Oberengstringen, Zentrum',
#        'Oberengstringen, Paradies', 'Unterengstringen, Langacher',
#        'Zürich, Vulkanstrasse', 'Zürich, Juchhof',
#        'Schlieren, Industrie Gaswerk', 'Schlieren, Rütistrasse',
#        'Schlieren, Brunngasse', 'Schlieren, Nassacker',
#        'Schlieren, Heimeliweg', 'Urdorf, Uitikonerstrasse',
#        'Urdorf Weihermatt, Bahnhof', 'Glanzenberg, Bahnhof',
#        'Dietikon, Schönenwerd', 'Urdorf, Rainweg',
#        'Urdorf, Neumattstrasse', 'Urdorf, Heinrich-Stutz-Strasse',
#        'Birmensdorf ZH, Ristet', 'Maur, Platten', 'Ebmatingen, Looren',
#        'Ebmatingen, Dorf', 'Ebmatingen, Leeacherstrasse',
#        'Binz bei Maur, Post', 'Binz bei Maur, Fridlimatt',
#        'Pfaffhausen, Müseren', 'Zürich, Friedhof Witikon',
#        'Zürich, Glockenacker', 'Benglen, Bodenacher',
#        'Benglen, Gerlisbrunnen', 'Pfaffhausen, Feldhof',
#        'Pfaffhausen, Sängglen', 'Pfaffhausen, Pfaffenstein',
#        'Fällanden, Schützenhaus', 'Fällanden, Eggler',
#        'Fällanden, Gemeindehaus', 'Fällanden, Industrie',
#        'Schwerzenbach ZH, Dorf', 'Fällanden, Bruggacher',
#        'Fällanden, Zil', 'Fällanden, Wigarten', 'Fällanden, Neuhus',
#        'Fällanden, Jugendherberge', 'Maur, Aschbach', 'Benglen, Langwis',
#        'Binz bei Maur, Bautacher', 'Dübendorf, Kämmaten',
#        'Gockhausen, Ursprungstrasse', 'Gockhausen, Dorf',
#        'Zürich, Tobelhof', 'Zürich, Zoo/Forrenweid', 'Zürich, Dreiwiesen',
#        'Zürich, Bircher-Benner', 'Itschnach, Fallacher',
#        'Itschnach, Dorf', 'Itschnach, Rebweg', 'Itschnach, Tägermoos',
#        'Küsnacht ZH, Schübel', 'Küsnacht ZH, Schiedhaldensteig',
#        'Küsnacht ZH, Schiedhaldenstr.', 'Küsnacht ZH, Boglerenstrasse',
#        'Küsnacht ZH, Goldbacherstrasse', 'Küsnacht ZH, Bühlstrasse',
#        'Zollikon, Goldhaldenplatz', 'Zollikon, Beugi',
#        'Zollikon, Dufourplatz', 'Zollikon, Felbenstrasse',
#        'Zollikon, Bahnübergang', 'Zürich, Elektrowatt',
#        'Zürich, Chinagarten', 'Küsnacht ZH, Allmend',
#        'Küsnacht ZH, Hesligenstrasse', 'Küsnacht ZH, Himmelistrasse',
#        'Küsnacht ZH, Bergstrasse', 'Küsnacht ZH, Oberwacht',
#        'Küsnacht ZH, Ränkestrasse', 'Zollikerberg, Resirain',
#        'Zollikerberg, Sennhof', 'Zollikerberg, Oberhueb',
#        'Küsnacht ZH, Bahnhof', 'Küsnacht ZH, Zentrum',
#        'Küsnacht ZH, Reform. Kirche', 'Küsnacht ZH, Hallenbad',
#        'Küsnacht ZH, Gartenstrasse', 'Küsnacht ZH, Oberfeld',
#        'Zumikon, Dorfzentrum', 'Zumikon, Waltikon', 'Zumikon, Gössikon'],
#       dtype=object)

# %%
start_station = 'Zürich, Feldeggstrasse'#'Zürich HB'
end_station = 'Zürich, Guggachstrasse'#'Dübendorf, Meiershofstrasse'#'Bassersdorf, Bahnhof'
total_dist = dist_between_station(metadata_df, start_station, end_station)
departure_time = pd.to_datetime('13.09.2017 8:15:00')#'13.09.2017 22:15:00'
#data_df_tr[col_of_interest][data_df_tr['STOP_STATION_NAME'] == start_station]
#lines = getLineID(data_df_tr, start_station, departure_time)

#data_df_tr['STOP_STATION_NAME'].unique()

# %%
import queue
#the queue contains a tuple (station, time at that station)
already_visited = []
q = queue.Queue()
q.put((start_station, departure_time))
closest_dist = total_dist
while(not q.empty()):
    s, time = q.get()
    already_visited.append(s)
    lines = getLineID(data_df_tr, s, time)
    print(s)
    #print(already_visited)
    for l in lines:
        #print(l)
        next_s_list = getNextStations2(data_df_tr, l, s)
        if len(next_s_list) == 0:
            next_s == None
        else:
            next_s = next_s_list[0]
        if next_s is not None:
            if next_s.STOP_STATION_NAME == end_station:
                print('End station founded')
            dist = dist_between_station(metadata_df,next_s.STOP_STATION_NAME, end_station)
            if next_s.STOP_STATION_NAME not in already_visited and\
                dist < total_dist:
                already_visited.append(next_s.STOP_STATION_NAME)
                q.put((next_s.STOP_STATION_NAME, next_s.ARRIVAL_TIME))
# Out:
# /home/charles/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# Zürich, Feldeggstrasse
# Zürich, Kreuzstrasse
# Zürich, Opernhaus
# Zürich, Bellevue
# Zürich, Bürkliplatz
# Zürich, Börsenstrasse
# Zürich, Helmhaus
# Zürich, Kunsthaus
# Zürich, Signaustrasse
# Zürich, Englischviertelstrasse
# Zürich, Rentenanstalt
# Zürich, Paradeplatz
# Zürich, Rathaus
# Zürich, Neumarkt
# Zürich, Hottingerplatz
# Zürich, Kantonsschule
# Zürich, Sprecherstrasse
# Zürich, Römerhof
# Zürich, Sihlstrasse
# Zürich, Waffenplatzstrasse
# Zürich, Schweizer Rück
# Zürich, Stockerstrasse
# Zürich, Rennweg
# Zürich, Rudolf-Brun-Brücke
# Zürich, Central
# Zürich, Platte
# Zürich, ETH/Universitätsspital
# Zürich, Hölderlinstrasse
# Zürich, Stauffacher
# Zürich,Kalkbreite/Bhf.Wiedikon
# Zürich, Tunnelstrasse
# Zürich, Bahnhofstrasse/HB
# Zürich, Löwenplatz
# Zürich, Bahnhofplatz/HB
# Zürich, Bahnhofquai/HB
# Zürich, Haldenegg
# Zürich, Voltastrasse
# Zürich, Haldenbach
# Zürich, Bezirksgebäude
# Zürich, Werd
# Zürich, Lochergut
# Zürich, Zwinglihaus
# Zürich, Kernstrasse
# Zürich, Zoo
# Zürich, Museum Rietberg
# Zürich, Seebacherplatz
# Zürich, Kanonengasse
# Zürich, Stampfenbachplatz
# Zürich, Sihlquai/HB
# Zürich, Beckenhof
# Zürich, Sonneggstrasse
# Zürich, Kirche Fluntern
# Zürich, Winkelriedstrasse
# Zürich, Schmiede Wiedikon
# Zürich, Zypressenstrasse
# Zürich, Goldbrunnenplatz
# Zürich, Helvetiaplatz
# Zürich, Felsenrainstrasse
# Zürich, Seebach
# Zürich, Hertensteinstrasse
# Zürich, Militär-/Langstrasse
# Zürich, Nordstrasse
# Zürich, Museum für Gestaltung
# Zürich, Kronenstrasse
# Zürich, Ottikerstrasse
# Zürich, Toblerplatz
# Zürich, Hofstrasse
# Zürich, Hinterbergstrasse
# Zürich, Seilbahn Rigiblick
# Zürich, Manesseplatz
# Zürich, Albisriederplatz
# Zürich, Talwiesenstrasse
# Zürich, Höfliweg
# Zürich, Gutstrasse
# Zürich, Sternen Oerlikon
# Zürich, Milchbuck
# Zürich, Ettenfeld
# Zürich, Ausserdorfstrasse
# Zürich, Buhnstrasse
# Zürich, Bäckeranlage
# Zürich, Röntgenstrasse
# Zürich, Limmatplatz
# Zürich, Rotbuchstrasse
# Zürich, Lettenstrasse
# Zürich, Schaffhauserplatz
# End station founded
# End station founded
# End station founded
# End station founded
# End station founded
# End station founded
# End station founded
# End station founded
# End station founded
# End station founded
# End station founded
# End station founded
# End station founded
# End station founded
# End station founded
# End station founded
# End station founded
# End station founded
# Zürich, Röslistrasse
# Zürich, Zürichbergstrasse
# Zürich, Klosbach
# Zürich, Spyriplatz
# Zürich, Kinkelstrasse
# Zürich, Vogelsangstrasse
# Zürich, Scheuchzerstrasse
# Zürich, Binz
# Zürich, Letzigrund
# Zürich, Hubertus
# Zürich, Hardplatz
# Zürich, Heuried
# Zürich, Im Gut
# Zürich, Leutschenbach
# Zürich, Salersteig
# Zürich, Messe/Hallenstadion
# Zürich, Regensbergbrücke
# Zürich, Dorflinde
# Zürich, Max-Bill-Platz
# Glattbrugg, Frohbühlstrasse
# Zürich, Birch-/Glatttalstrasse
# Zürich, Friedhof Schwandenholz
# Zürich, Himmeri
# Zürich, Schönauring
# Zürich, Güterbahnhof
# Zürich, Quellenstrasse
# Zürich, Lägernstrasse
# Zürich, Nürenbergstrasse
# Zürich, Okenstrasse
# Zürich, Rosengartenstrasse
# Zürich, Guggachstrasse
# Zürich, Laubiweg
# Zürich, Susenbergstrasse
# Zürich, Hölderlinsteig
# Zürich, Bethanien
# Zürich, Letzistrasse
# Zürich, Freihofstrasse
# Zürich, Siemens
# Zürich, Albisrank
# Zürich, Herdernstrasse
# Zürich, Schiffbau
# Zürich, Langgrütstrasse
# Zürich, Oerlikerhus
# Zürich, Berninaplatz
# Zürich, Hallenbad Oerlikon
# Zürich, Bad Allenmoos
# Zürich, Oberwiesenstrasse
# Zürich, Friedackerstrasse
# Zürich, Maillartstrasse
# Zürich, Bollingerweg
# Zürich, Birchstrasse
# Zürich, Im Ebnet
# Zürich, Leimgrübelstrasse
# Zürich, Staudenbühl
# Zürich, Neunbrunnen
# Zürich, Köschenrüti
# Zürich, Dammweg
# Zürich, Bucheggplatz
# Zürich, Escher-Wyss-Platz
# Zürich, Lehenstrasse
# Zürich, Langmauerstrasse
# Zürich, Kappeli
# Zürich, Flurstrasse
# Zürich, SBB-Werkstätte
# Zürich, Technopark
# Glattbrugg, Lindberghplatz
# Zürich, Fernsehstudio
# Zürich, Hirschwiesenstrasse
# Zürich, Riedgraben
# Zürich, Radiostudio
# Zürich, Neuaffoltern
# Zürich, Waldgarten
# Zürich, Chaletweg
# Zürich, Käshaldenstrasse
# Zürich, Hürstholz
# Zürich, Stierenried
# Zürich, Weihersteig
# Zürich, Wipkingerplatz
# Zürich, Förrlibuckstrasse
# Zürich, Rebbergsteig
# Zürich, Universität Irchel
# Zürich, Grimselstrasse
# Zürich, Letzipark West
# Zürich, Letzipark
# Zürich, Toni-Areal
# Zürich, Auzelg
# Zürich, Saatlenstrasse
# Zürich, Birchdörfli
# Zürich, Glaubtenstrasse
# Zürich, Tierspital
# Zürich, Schörlistrasse
# Zürich, Frohburg
# Zürich, Mötteliweg
# Zürich, Glaubtenstrasse Nord
# Zürich, Waidspital
# Zürich, Waidfussweg
# Zürich, Fischerweg
# Zürich, Kempfhofsteig
# Zürich, Baslerstrasse
# Zürich, Luggwegstrasse
# Zürich, Sportweg
# Wallisellen, Herti
# Zürich, Auzelg Ost
# Zürich, Orionstrasse
# Zürich, Dreispitz
# Zürich, Einfangstrasse
# Zürich, Althoos
# Zürich, Schwamendingerplatz
# Zürich, Friedrichstrasse
# Zürich, Schumacherweg
# Zürich, Pflegezentr. Käferberg
# Zürich, Eschergutweg
# Zürich, Bernoulli-Häuser
# Zürich, Schwert
# Zürich, Aargauerstrasse
# Zürich, Aubrücke
# Zürich, Zehntenhausplatz
# Zürich, Maienweg
# Zürich, Roswiesen
# Zürich, Heerenwiesen
# Zürich, Lerchenhalde
# Zürich, Glaubtenstrasse Süd
# Zürich, Waidbadstrasse
# Zürich, Alte Trotte
# Zürich, Hardturm
# Zürich, Meierhofplatz
# Zürich, Am Börtli
# Zürich, Würzgraben
# Zürich, Herzogenmühlestrasse
# Zürich, Schürgistrasse
# Zürich, ETH Hönggerberg
# Zürich, Schauenberg
# Zürich, Fronwald
# Zürich, Krematorium Nordheim
# Zürich, Glattwiesen
# Zürich, Luegisland
# Zürich, Lerchenrain
# Zürich, Appenzellerstrasse
# Zürich, Im Wingert
# Zürich, Hardhof
# Zürich, Zwielplatz
# Zürich, Kappenbühlweg
# Zürich, Wieslergasse
# Zürich, Hönggerberg
# Zürich, Luchswiesen
# Zürich, Unteraffoltern
# Zürich, Nordheimstrasse
# Zürich, Probstei
# Zürich, Tüffenwies
# Zürich, Wartau
# Zürich, Michelstrasse
# Zürich, Singlistrasse
# Zürich, Altried
# Zürich, Schwandenholz
# Zürich, Berufswahlschule
# Zürich, Mattenhof
# Zürich, Grünaustrasse
# Zürich, Winzerhalde
# Zürich, Friedhof Hönggerberg
# Zürich, Segantinistrasse
# Zürich, Hirzenbach
# Zürich, Waidhof
# Zürich, Hohenklingensteig
# Zürich, Schützenhaus Höngg

# %%
#TODO visualize on map all the stops that the algo has seen
#can be good to check that the heuristic is not going to a wrong direction
#DONE

#TODO Tag a station as having conection and with wich line it has connection 
# or for each station get to list of line_id connection precomputed
# including nearby station by walk

# %%
import folium
my_map = folium.Map(location=loc)
folium.Marker(getLongLat(metadata_df, start_station)).add_to(my_map)
folium.Marker(getLongLat(metadata_df, end_station)).add_to(my_map)
for place in already_visited:
    l = getLongLat(metadata_df, place)
    #folium.Marker(location=l).add_to(my_map)
    folium.RegularPolygonMarker(
    l,
    fill_color='#132b5e',
    number_of_sides=3,
    radius=3
    ).add_to(my_map)
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Todo vizualize all the lines to see if they are connected
